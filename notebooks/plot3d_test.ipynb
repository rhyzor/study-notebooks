# %%
import sympy as sp
from sympy.plotting import plot3d

# %%
x,y = sp.symbols('x,y')

# %%
f = 0.8*x+20*y
f
# Out:
# 0.8*x + 20*y

# %%
plot3d(f);

# %%
f2 = x*y/sp.sqrt(x**2+y**2-5)
f2
# Out:
# x*y/sqrt(x**2 + y**2 - 5)

# %%
plot3d(f2);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plot3d(f2);
#
# File ~/Desktop/study_notebooks/ml_env/lib/python3.12/site-packages/sympy/plotting/plot.py:922, in plot3d(show, *args, **kwargs)
#     791 """
#     792 Plots a 3D surface plot.
#     793
#    (...)    919
#     920 """
#     921 kwargs.setdefault("show", show)
# --> 922 return _plot3d_plot_contour_helper(
#     923     SurfaceOver2DRangeSeries, *args, **kwargs)
#
# File ~/Desktop/study_notebooks/ml_env/lib/python3.12/site-packages/sympy/plotting/plot.py:786, in _plot3d_plot_contour_helper(Series, *args, **kwargs)
#     784 plots = plot_factory(*series, **kwargs)
#     785 if kwargs.get("show", True):
# --> 786     plots.show()
#     787 return plots
#
# ...

# %% [markdown]
# # Practice #

# %%
f_1 = sp.sin(sp.sqrt(x**2+y**2))
f_1
# Out:
# sin(sqrt(x**2 + y**2))

# %%
plot3d(f_1);

# %%
f_2 = sp.exp(-0.9*x**2-0.45*(x-y)**2)
f_2
# Out:
# exp(-0.9*x**2 - 0.45*(x - y)**2)

# %%
plot3d(f_2,);

# %%
plot3d(f_2,
      (x,-3,3), (y,-3,3)
      );

# %%
f_3 = x*sp.cos(y)
f_3
# Out:
# x*cos(y)

# %%
plot3d(f_3);

# %%
sp.solve(f_3) #test
# Out:
# [{x: 0}, {y: pi/2}, {y: 3*pi/2}]

# %%
f_4 = 5*x-3*y+2
f_4
# Out:
# 5*x - 3*y + 2

# %%
plot3d(f_4);

# %%
sp.solve(f_4)
# Out:
# [{x: 3*y/5 - 2/5}]

# %%
f_4_x = 3/5 * y - 2/5
f_4_x
# Out:
# 0.6*y - 0.4

# %%
sp.plot(f_4_x);

# %% [markdown]
# # Task 2

# %% [markdown]
# найти нули и построить графики если возможно

# %%
f_5 = 2*x+5*y+1
f_5
# Out:
# 2*x + 5*y + 1

# %%
plot3d(f_5);

# %%
f_6 = x**2+y**2-1 # Подсказка: для построения графика нулей используйте такой промежуток для переменной в функции plot: (y,-1,1).

f_6
# Out:
# x**2 + y**2 - 1

# %%
plot3d(f_6);

# %%
f_7 = x * sp.cos(y)
f_7
# Out:
# x*cos(y)

# %%
plot3d(f_7);

# %% [markdown]
# Находим нули:

# %%
sp.solve(f_5)
# Out:
# [{x: -5*y/2 - 1/2}]

# %%
f_5_x = -5*y/2-1/2
f_5_x
# Out:
# -5*y/2 - 0.5

# %%
sp.plot(f_5_x);

# %%
sp.solve(f_6)
# Out:
# [{x: -sqrt(1 - y**2)}, {x: sqrt(1 - y**2)}]

# %%
f_6_x_1 = -sp.sqrt(1-y**2)
f_6_x_1
# Out:
# -sqrt(1 - y**2)

# %%
f_6_x_2 = sp.sqrt(1-y**2)
f_6_x_2
# Out:
# sqrt(1 - y**2)

# %%
sp.plot(f_6_x_1);

# %%
sp.plot(f_6_x_2);

# %%
sp.solve(f_7)
# Out:
# [{x: 0}, {y: pi/2}, {y: 3*pi/2}]

# %%
import pandas as pd

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split, cross_validate, cross_val_score

# %%
df = pd.read_csv('../data/stroke_data_encoded.csv')
df
# Out:
#       gender        age  hypertension  heart_disease  ever_married  work_type  \
# 0          0  72.917651             0              0             1          0
# 1          1  49.000000             0              0             1          0
# 2          0  58.111818             0              0             1          0
# 3          1  69.000000             0              0             1          1
# 4          0  60.000000             0              0             1          0
# ...      ...        ...           ...            ...           ...        ...
# 3995       0  40.000000             0              0             0          2
# 3996       0  63.570937             0              0             1          1
# 3997       0  80.000000             0              1             1          0
# 3998       1  41.000000             0              0             1          0
# 3999       0  31.000000             0              0             1          0
#
#       Residence_type  avg_glucose_level        bmi  smoking_status  stroke
# 0                  1         143.509078  29.160236               0       1
# 1                  0          85.230000  25.400000               3       0
# 2                  0         197.174377  34.870606               0       1
# 3                  1          99.680000  17.600000               0       0
# 4                  0          69.200000  30.900000               1       0
# ...              ...                ...        ...             ...     ...
# 3995               1         197.110000  23.900000               1       0
# 3996               0         114.000886  32.598340               0       1
# 3997               0          67.464694  22.728583               0       1
# 3998               1          80.720000  34.100000               2       0
# 3999               0         100.520000  29.900000               3       0
#
# [4000 rows x 11 columns]

# %%
df.shape
# Out:
# (4000, 11)

# %%
x = df.drop(['stroke'], axis=1)
y = df.stroke

# %%
logreg = LogisticRegression(random_state=42, max_iter=500)

# %%
cross_validate(logreg,x,y, cv=5)
# Out:
# {'fit_time': array([0.0743289 , 0.0569489 , 0.04781437, 0.05507517, 0.06540728]),
#  'score_time': array([0.00117612, 0.0009501 , 0.00085187, 0.00085497, 0.00104785]),
#  'test_score': array([0.82625, 0.84625, 0.81375, 0.84125, 0.81125])}

# %%
cv_score = cross_val_score(logreg,x,y, cv=5,)

# %%
cv_score.mean(), cv_score.std()
# Out:
# (np.float64(0.82775), np.float64(0.014106735979665878))

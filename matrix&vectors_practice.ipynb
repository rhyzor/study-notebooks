# %%
import numpy as np

# %% [markdown]
# # Task 1

# %% [markdown]
# ![image.png](attachment:1d346ff4-5025-4f80-96b5-f5cdf32910ef.png)

# %%
# 1
a = np.array([2,5,0,6,8,10,6,7,5,7])
b = np.array([8,6,7,9,6,6,2,3,2,3])

(3*a) @ (2*b)
# Out:
# np.int64(1632)

# %%
np.dot(3*a,2*b)
# Out:
# np.int64(1632)

# %%
# 2
a = np.array([9,6,7,7,0,1,6,8,1,2])
b = np.array([0,2,2,6,7,8,8,3,1,8])

np.dot(6*a,5*b)
# Out:
# np.int64(4950)

# %%
# 3
a = np.array([2,5,0,6,8,10,6,7,5,7])
b = np.array([8,6,7,9,6,6,2,3,2,3])

np.dot(a,b)
# Out:
# np.int64(272)

# %%
# 4
a = np.array([9,6,7,7,0,1,6,8,1,2])
b = np.array([0,2,2,6,7,8,8,3,1,8])

np.dot(a,b)
# Out:
# np.int64(165)

# %% [markdown]
# Ответы:
# 1) 1632
# 2) 4950
# 3) 272
# 3) 165

# %% [markdown]
# # Task 2

# %% [markdown]
# ![image.png](attachment:1711d791-df02-453c-ad76-4c271f2b1fc2.png)

# %%
matrix1 = np.array([
    (2, 1, 7, 4),
    (5,6,7,3),
    (9,8,2,12),
    (11,14,15,15)
])

t_matrix1 = matrix1.transpose()
t_matrix1
# Out:
# array([[ 2,  5,  9, 11],
#        [ 1,  6,  8, 14],
#        [ 7,  7,  2, 15],
#        [ 4,  3, 12, 15]])

# %%
matrix2 = np.array([
    (3, 7, 8, 3, 6),
    (2, 5, 9, 4, 13)
])

t_matrix2 = matrix2.transpose()
t_matrix2
# Out:
# array([[ 3,  2],
#        [ 7,  5],
#        [ 8,  9],
#        [ 3,  4],
#        [ 6, 13]])

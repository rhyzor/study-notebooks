# %%
import sympy as sp
from sympy.plotting import plot, plot3d

# %% [markdown]
# ![image.png](attachment:7e7ee8b3-f823-48c4-80ee-248364206021.png)"

# %%
x0, x1, x2, y, a1, a2 = sp.symbols('x0, x1, x2, y, a1, a2')
a0 = sp.Symbol('a0')

# %%
MSE = 1/3 * (((a2*30 + a1*10 + a0) + 7)**2 + \
            ((a2*15 - a1*5 + a0) + 20)**2 + \
            ((a2*31+ a1*16 + a0) - 4)**2)

MSE
# Out:
# 0.333333333333333*(a0 - 5*a1 + 15*a2 + 20)**2 + 0.333333333333333*(a0 + 10*a1 + 30*a2 + 7)**2 + 0.333333333333333*(a0 + 16*a1 + 31*a2 - 4)**2

# %%
MSE.subs({a2:-2, a1: 1, a0: -7})
# Out:
# 2077.66666666667

# %%
MSE.subs({a2:20, a1: 3, a0: -4})
# Out:
# 308963.333333333

# %%
f1 = -2*x2+x1-7
f2 = 20*x2+3*x1-4

# %%
plot3d(f1);

# %%
plot3d(f2);

# %% [markdown]
# ![image.png](attachment:c6969abe-2d57-4955-9edd-7e0de2499c03.png)

# %%
MSE2 = 1/3 * (((a2*17 + a1*16 + a0) - 13)**2 + \
            ((a2*28 + a1*(-3) + a0) - 42)**2 + \
            ((a2*85+ a1*14 + a0) + 39)**2)

MSE2
# Out:
# 0.333333333333333*(a0 - 3*a1 + 28*a2 - 42)**2 + 0.333333333333333*(a0 + 14*a1 + 85*a2 + 39)**2 + 0.333333333333333*(a0 + 16*a1 + 17*a2 - 13)**2

# %%
MSE2.subs(
        {a2:-2, a1:-1, a0: 60}
)
# Out:
# 2819.66666666667

# %%
MSE2.subs(
        {a2:2, a1:17, a0: -9}
)
# Out:
# 91538.6666666667

# %% [markdown]
# ![image.png](attachment:f167ffc6-b9a2-40d4-9de0-c2e740c49b65.png)

# %%
MSE3 = 1/3 * (((a2*39+a1*7+a0)+60)**2 + \
           ((a2*48+a1*12+a0)-17)**2 + \
           ((a2*55+a1*3+a0)-83)**2)
MSE3
# Out:
# 0.333333333333333*(a0 + 3*a1 + 55*a2 - 83)**2 + 0.333333333333333*(a0 + 7*a1 + 39*a2 + 60)**2 + 0.333333333333333*(a0 + 12*a1 + 48*a2 - 17)**2

# %%
MSE3.subs({a2:-4, a1:7, a0:-11})
# Out:
# 35903.0000000000

# %%
MSE3.subs({a2:-0.5, a1:9, a0:-400})
# Out:
# 144191.166666667
